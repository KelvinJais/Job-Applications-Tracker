# %%
import json
with open('annotations86.json', 'r') as file:
    data = json.load(file)
i=0
print(data)

# %%
ideal_format=[]
for row in data["annotations"]:
    entities=[tuple(i) for i in row[1]['entities']]
    print(entities)
# Out:
# ([78, 85, 'COMPANY'], [139, 145, 'COMPANY'], [292, 299, 'COMPANY'])
# ([171, 229, 'JOB TITLE'], [233, 257, 'COMPANY'], [402, 425, 'COMPANY'], [649, 672, 'COMPANY'], [842, 865, 'COMPANY'])
# ([73, 93, 'COMPANY'], [142, 162, 'COMPANY'], [206, 244, 'JOB TITLE'], [494, 513, 'COMPANY'], [675, 694, 'COMPANY'])
# ([7, 14, 'COMPANY'], [240, 319, 'JOB TITLE'], [721, 728, 'COMPANY'], [793, 881, 'JOB TITLE'], [922, 1010, 'JOB TITLE'])
# ([73, 88, 'COMPANY'], [125, 141, 'COMPANY'], [327, 332, 'COMPANY'], [340, 355, 'COMPANY'])
# ([73, 81, 'COMPANY'], [123, 130, 'COMPANY'], [292, 299, 'COMPANY'])
# ([18, 29, 'COMPANY'], [67, 77, 'COMPANY'], [425, 435, 'COMPANY'], [512, 528, 'COMPANY'])
# ([7, 14, 'COMPANY'], [79, 86, 'COMPANY'], [184, 202, 'JOB TITLE'], [612, 619, 'COMPANY'], [656, 663, 'COMPANY'])
# ([73, 79, 'COMPANY'], [133, 139, 'COMPANY'], [183, 223, 'JOB TITLE'], [1010, 1016, 'COMPANY'], [1157, 1163, 'COMPANY'], [1280, 1286, 'COMPANY'], [2811, 2817, 'COMPANY'], [3019, 3025, 'COMPANY'], [3251, 3257, 'COMPANY'])
# ([7, 61, 'COMPANY'], [115, 150, 'JOB TITLE'], [154, 193, 'COMPANY'], [246, 281, 'JOB TITLE'], [302, 341, 'COMPANY'], [489, 527, 'COMPANY'], [691, 733, 'COMPANY'])
# ([7, 10, 'COMPANY'], [225, 283, 'JOB TITLE'], [745, 748, 'COMPANY'])
# ([72, 84, 'COMPANY'], [145, 165, 'JOB TITLE'], [174, 186, 'COMPANY'], [555, 566, 'COMPANY'], [582, 593, 'COMPANY'])
# ([88, 96, 'COMPANY'], [97, 152, 'JOB TITLE'], [295, 365, 'JOB TITLE'], [381, 388, 'COMPANY'], [433, 441, 'COMPANY'])
# ([8, 40, 'COMPANY'], [109, 140, 'COMPANY'], [200, 232, 'JOB TITLE'], [245, 277, 'COMPANY'], [664, 696, 'COMPANY'], [779, 835, 'COMPANY'])
# ([73, 85, 'COMPANY'], [155, 166, 'COMPANY'], [208, 228, 'JOB TITLE'], [682, 693, 'COMPANY'], [898, 909, 'COMPANY'])
# ([73, 80, 'COMPANY'], [118, 125, 'COMPANY'], [289, 295, 'COMPANY'])
# ([68, 74, 'COMPANY'], [102, 127, 'JOB TITLE'], [196, 202, 'COMPANY'], [240, 264, 'JOB TITLE'], [620, 627, 'COMPANY'], [954, 960, 'COMPANY'])
# ([73, 105, 'COMPANY'], [150, 190, 'JOB TITLE'], [194, 226, 'COMPANY'], [484, 492, 'COMPANY'], [559, 567, 'COMPANY'])
# ([7, 27, 'COMPANY'], [96, 117, 'COMPANY'], [164, 184, 'COMPANY'], [245, 269, 'JOB TITLE'], [563, 583, 'COMPANY'])
# ([7, 14, 'COMPANY'], [109, 174, 'JOB TITLE'], [473, 480, 'COMPANY'], [545, 633, 'JOB TITLE'], [674, 762, 'JOB TITLE'], [867, 879, 'COMPANY'])
# ([70, 111, 'JOB TITLE'], [124, 129, 'COMPANY'], [189, 246, 'JOB TITLE'], [250, 255, 'COMPANY'], [476, 480, 'COMPANY'], [574, 579, 'COMPANY'], [637, 641, 'COMPANY'])
# ([61, 66, 'COMPANY'], [141, 189, 'JOB TITLE'], [195, 199, 'COMPANY'], [278, 282, 'COMPANY'], [818, 822, 'COMPANY'])
# ([7, 27, 'COMPANY'], [96, 117, 'COMPANY'], [164, 184, 'COMPANY'], [245, 263, 'JOB TITLE'], [557, 577, 'COMPANY'])
# ([7, 10, 'COMPANY'], [71, 74, 'COMPANY'], [79, 152, 'JOB TITLE'], [209, 267, 'JOB TITLE'], [349, 352, 'COMPANY'], [469, 472, 'COMPANY'])
# ([178, 210, 'JOB TITLE'], [422, 430, 'COMPANY'], [439, 442, 'COMPANY'], [626, 644, 'COMPANY'])
# ([80, 86, 'COMPANY'], [180, 219, 'JOB TITLE'], [1106, 1113, 'COMPANY'], [1161, 1167, 'COMPANY'], [1352, 1378, 'COMPANY'])
# ([73, 80, 'COMPANY'], [139, 146, 'COMPANY'], [183, 199, 'JOB TITLE'], [429, 436, 'COMPANY'])
# ([47, 73, 'COMPANY'], [409, 435, 'COMPANY'])
# ([7, 16, 'COMPANY'], [82, 92, 'COMPANY'], [136, 145, 'COMPANY'], [468, 477, 'COMPANY'])
# ([7, 14, 'COMPANY'], [75, 82, 'COMPANY'], [144, 151, 'COMPANY'], [226, 259, 'JOB TITLE'], [461, 472, 'COMPANY'])
# ([73, 82, 'COMPANY'], [117, 126, 'COMPANY'], [290, 298, 'COMPANY'])
# ([73, 85, 'COMPANY'], [120, 132, 'COMPANY'], [296, 307, 'COMPANY'])
# ([114, 121, 'COMPANY'], [191, 234, 'JOB TITLE'], [446, 451, 'COMPANY'], [610, 615, 'COMPANY'], [823, 828, 'COMPANY'], [1098, 1108, 'COMPANY'])
# ([7, 12, 'COMPANY'], [114, 121, 'COMPANY'], [192, 236, 'JOB TITLE'], [448, 453, 'COMPANY'], [612, 617, 'COMPANY'], [639, 644, 'COMPANY'], [952, 957, 'COMPANY'], [1100, 1110, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [142, 148, 'COMPANY'], [209, 236, 'COMPANY'], [533, 539, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [205, 229, 'JOB TITLE'], [526, 532, 'COMPANY'])
# ([145, 177, 'COMPANY'], [178, 231, 'JOB TITLE'], [844, 846, 'COMPANY'], [1141, 1143, 'COMPANY'], [1255, 1257, 'COMPANY'])
# ([143, 175, 'COMPANY'], [176, 196, 'JOB TITLE'], [756, 758, 'COMPANY'], [809, 811, 'COMPANY'], [1106, 1108, 'COMPANY'], [1220, 1222, 'COMPANY'])
# ([62, 72, 'COMPANY'], [235, 245, 'COMPANY'])
# ([149, 187, 'JOB TITLE'], [199, 203, 'COMPANY'])
# ([7, 56, 'COMPANY'], [119, 147, 'JOB TITLE'], [158, 197, 'COMPANY'], [256, 284, 'JOB TITLE'], [312, 350, 'COMPANY'], [513, 566, 'COMPANY'])
# ([7, 14, 'COMPANY'], [75, 82, 'COMPANY'], [138, 145, 'COMPANY'], [220, 253, 'JOB TITLE'], [455, 466, 'COMPANY'])
# ([7, 14, 'COMPANY'], [75, 82, 'COMPANY'], [140, 147, 'COMPANY'], [222, 260, 'JOB TITLE'], [462, 473, 'COMPANY'])
# ([7, 18, 'COMPANY'], [66, 98, 'JOB TITLE'], [101, 113, 'COMPANY'], [201, 212, 'COMPANY'], [553, 564, 'COMPANY'])
# ([95, 103, 'COMPANY'], [153, 161, 'COMPANY'], [305, 342, 'JOB TITLE'], [518, 525, 'COMPANY'])
# ([95, 103, 'COMPANY'], [150, 158, 'COMPANY'], [302, 360, 'JOB TITLE'], [536, 543, 'COMPANY'])
# ([83, 89, 'COMPANY'], [154, 193, 'JOB TITLE'], [578, 583, 'COMPANY'], [763, 768, 'COMPANY'], [846, 872, 'COMPANY'])
# ([67, 76, 'COMPANY'], [119, 146, 'JOB TITLE'], [540, 548, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 249, 'JOB TITLE'], [543, 549, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 241, 'JOB TITLE'], [535, 541, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [136, 142, 'COMPANY'], [203, 265, 'JOB TITLE'], [559, 565, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 241, 'JOB TITLE'], [535, 541, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 232, 'JOB TITLE'], [526, 532, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [136, 142, 'COMPANY'], [203, 245, 'JOB TITLE'], [539, 545, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [204, 242, 'JOB TITLE'], [536, 542, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [136, 142, 'COMPANY'], [203, 247, 'JOB TITLE'], [541, 547, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 239, 'JOB TITLE'], [533, 539, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 229, 'JOB TITLE'], [523, 529, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [204, 243, 'JOB TITLE'], [537, 543, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [137, 143, 'COMPANY'], [188, 231, 'JOB TITLE'], [525, 531, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [141, 147, 'COMPANY'], [208, 236, 'JOB TITLE'], [530, 536, 'COMPANY'])
# ([8, 29, 'COMPANY'], [165, 178, 'JOB TITLE'])
# ([89, 127, 'JOB TITLE'], [217, 251, 'JOB TITLE'], [257, 271, 'COMPANY'], [1031, 1044, 'COMPANY'])
# ([20, 25, 'COMPANY'], [83, 89, 'COMPANY'], [154, 205, 'JOB TITLE'], [590, 595, 'COMPANY'], [775, 780, 'COMPANY'], [858, 884, 'COMPANY'])
# ([20, 25, 'COMPANY'], [83, 89, 'COMPANY'], [151, 202, 'JOB TITLE'], [587, 592, 'COMPANY'], [772, 777, 'COMPANY'], [854, 880, 'COMPANY'])
# ([20, 25, 'COMPANY'], [83, 89, 'COMPANY'], [154, 207, 'JOB TITLE'], [592, 597, 'COMPANY'], [777, 782, 'COMPANY'], [860, 886, 'COMPANY'])
# ([95, 103, 'COMPANY'], [152, 160, 'COMPANY'], [304, 348, 'JOB TITLE'], [524, 531, 'COMPANY'])
# ([20, 25, 'COMPANY'], [83, 89, 'COMPANY'], [153, 209, 'JOB TITLE'], [594, 599, 'COMPANY'], [779, 784, 'COMPANY'], [863, 889, 'COMPANY'])
# ([7, 11, 'COMPANY'], [70, 107, 'JOB TITLE'], [120, 125, 'COMPANY'], [181, 225, 'JOB TITLE'], [238, 243, 'COMPANY'], [464, 468, 'COMPANY'], [562, 567, 'COMPANY'], [625, 629, 'COMPANY'])
# ([93, 110, 'COMPANY'], [161, 177, 'COMPANY'], [186, 222, 'JOB TITLE'], [719, 735, 'COMPANY'])
# ([73, 97, 'JOB TITLE'], [101, 116, 'COMPANY'], [142, 166, 'JOB TITLE'], [170, 184, 'COMPANY'], [522, 536, 'COMPANY'], [537, 561, 'JOB TITLE'], [562, 576, 'COMPANY'], [681, 714, 'JOB TITLE'], [718, 732, 'COMPANY'], [898, 920, 'COMPANY'], [921, 935, 'COMPANY'])
# ([89, 123, 'COMPANY'], [194, 227, 'COMPANY'], [249, 308, 'JOB TITLE'], [950, 1015, 'JOB TITLE'])
# ([7, 16, 'COMPANY'], [93, 132, 'JOB TITLE'], [136, 146, 'COMPANY'], [208, 218, 'COMPANY'], [257, 297, 'JOB TITLE'], [633, 642, 'COMPANY'])
# ([17, 25, 'COMPANY'], [90, 105, 'COMPANY'], [164, 172, 'COMPANY'], [193, 235, 'JOB TITLE'], [615, 623, 'COMPANY'])
# ([7, 11, 'COMPANY'], [70, 108, 'JOB TITLE'], [121, 126, 'COMPANY'], [182, 227, 'JOB TITLE'], [240, 245, 'COMPANY'], [477, 481, 'COMPANY'], [575, 580, 'COMPANY'], [638, 642, 'COMPANY'])
# ([78, 84, 'COMPANY'], [94, 116, 'JOB TITLE'], [174, 180, 'COMPANY'], [187, 208, 'JOB TITLE'], [415, 426, 'COMPANY'], [831, 837, 'COMPANY'])
# ([417, 450, 'COMPANY'], [555, 588, 'COMPANY'])
# ([141, 169, 'JOB TITLE'], [269, 272, 'COMPANY'])
# ([7, 13, 'COMPANY'], [82, 89, 'COMPANY'], [136, 142, 'COMPANY'], [203, 229, 'JOB TITLE'], [523, 529, 'COMPANY'])
# ([73, 90, 'COMPANY'], [136, 146, 'COMPANY'], [521, 558, 'JOB TITLE'], [664, 680, 'COMPANY'])
# ([61, 89, 'JOB TITLE'], [147, 174, 'JOB TITLE'], [444, 449, 'COMPANY'], [520, 570, 'JOB TITLE'], [610, 660, 'JOB TITLE'])
# ([8, 35, 'COMPANY'], [121, 149, 'COMPANY'], [223, 235, 'JOB TITLE'], [248, 276, 'COMPANY'], [507, 534, 'COMPANY'])
# ([7, 13, 'COMPANY'], [79, 123, 'JOB TITLE'], [127, 134, 'COMPANY'], [210, 253, 'JOB TITLE'], [508, 515, 'COMPANY'])
# ([7, 13, 'COMPANY'], [112, 125, 'COMPANY'], [179, 213, 'JOB TITLE'], [401, 408, 'COMPANY'], [409, 415, 'COMPANY'])
# ([90, 106, 'JOB TITLE'], [185, 200, 'COMPANY'], [204, 212, 'JOB TITLE'], [648, 655, 'COMPANY'], [671, 678, 'COMPANY'], [800, 833, 'JOB TITLE'])
# ([72, 77, 'COMPANY'], [129, 134, 'COMPANY'], [156, 187, 'JOB TITLE'], [588, 593, 'COMPANY'])
